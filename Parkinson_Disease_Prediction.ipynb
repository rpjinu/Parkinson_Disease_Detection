# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn import svm
#ignore warning
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #Load the Parkinson dataset

# %%
#read csv file
df=pd.read_csv('/content/parkinsons_2.csv')

# %%
df
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
# ...

# %%
#getting more info about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
#check the column list
df.shape
# Out:
# (195, 24)

# %%
#check the null values
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
#check the duplicate data
df.duplicated().sum()
# Out:
# 0

# %%
#statistical data about the dataset
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
# target variable = status
df['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
# Drop the 'name' column as it's not useful for prediction
df = df.drop(columns=['name'])

# %% [markdown]
# #Correlation of Feature

# %%
#correlation between feature
df.corr()
# Out:
#                   MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# MDVP:Fo(Hz)          1.000000      0.400985      0.596546       -0.118003
# MDVP:Fhi(Hz)         0.400985      1.000000      0.084951        0.102086
# MDVP:Flo(Hz)         0.596546      0.084951      1.000000       -0.139919
# MDVP:Jitter(%)      -0.118003      0.102086     -0.139919        1.000000
# MDVP:Jitter(Abs)    -0.382027     -0.029198     -0.277815        0.935714
# MDVP:RAP            -0.076194      0.097177     -0.100519        0.990276
# MDVP:PPQ            -0.112165      0.091126     -0.095828        0.974256
# Jitter:DDP          -0.076213      0.097150     -0.100488        0.990276
# MDVP:Shimmer        -0.098374      0.002281     -0.144543        0.769063
# MDVP:Shimmer(dB)    -0.073742      0.043465     -0.119089        0.804289
# Shimmer:APQ3        -0.094717     -0.003743     -0.150747        0.746625
# Shimmer:APQ5        -0.070682     -0.009997     -0.101095        0.725561
# ...

# %%
#corelation chart
plt.figure(figsize=(16,12))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# #Seperating Other variables and Target Variables

# %%
X = df.drop(columns=['status'], axis=1) # Features
y = df['status'] # Target

# %% [markdown]
# #Splitting data into testing and training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (195, 22) (156, 22) (39, 22)

# %% [markdown]
# #Data Standardization

# %%
sc = StandardScaler()
sc.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# #*Model Training*

# %%
# Initialize the models
models = {
    "Logistic Regression": LogisticRegression(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Support Vector Machine": SVC(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Gradient Boosting": GradientBoostingClassifier()
}

# %%
# Train and evaluate each model
results = {}

for model_name, model in models.items():
    # Train the model
    model.fit(X_train, y_train)

    # Predict on the test set
    y_pred = model.predict(X_test)

    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    results[model_name] = accuracy
    print(f"{model_name} - Accuracy: {accuracy:.4f}")
    print(classification_report(y_test, y_pred))
    print("-" * 50)
# Out:
# Logistic Regression - Accuracy: 0.8205
#               precision    recall  f1-score   support
#
#            0       0.56      0.62      0.59         8
#            1       0.90      0.87      0.89        31
#
#     accuracy                           0.82        39
#    macro avg       0.73      0.75      0.74        39
# weighted avg       0.83      0.82      0.82        39
#
# --------------------------------------------------
# K-Nearest Neighbors - Accuracy: 0.7692
#               precision    recall  f1-score   support
#
#            0       0.46      0.75      0.57         8
#            1       0.92      0.77      0.84        31
#
#     accuracy                           0.77        39
#    macro avg       0.69      0.76      0.71        39
# weighted avg       0.83      0.77      0.79        39
#
# --------------------------------------------------
# Support Vector Machine - Accuracy: 0.8974
#               precision    recall  f1-score   support
#
# ...

# %% [markdown]
# #find the best model

# %%
# Display the accuracy of each model
for model_name, accuracy in results.items():
    print(f"{model_name}: {accuracy:.4f}")
# Out:
# Logistic Regression: 0.8205
# K-Nearest Neighbors: 0.7692
# Support Vector Machine: 0.8974
# Decision Tree: 0.7692
# Random Forest: 0.8462
# Gradient Boosting: 0.8205

# %%
# Identify the best model based on accuracy
best_model_name = max(results, key=results.get)
best_model = models[best_model_name]

print(f"Best Model: {best_model_name} with Accuracy: {results[best_model_name]:.4f}")
# Out:
# Best Model: Support Vector Machine with Accuracy: 0.8974

# %% [markdown]
# #Best model is SVC train and save

# %%
#We will train the model using Support Vector Machine (SVM)
model = svm.SVC(kernel='linear')

# %%
# training the SVM model with training data
model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# #Model Evaluation

# %%
# Accuracy Score on training data
X_train_pred = model.predict(X_train)
training_data_accuracy = accuracy_score(y_train, X_train_pred)

# %%
print('Accuracy (Training Data) :', training_data_accuracy*100, '%')
# Out:
# Accuracy (Training Data) : 88.46153846153845 %

# %%
# Accuracy Score on test data
X_test_pred = model.predict(X_test)
testing_data_accuracy = accuracy_score(y_test, X_test_pred)

# %%
print('Accuracy (Testing Data) :', testing_data_accuracy*100, '%')
# Out:
# Accuracy (Testing Data) : 87.17948717948718 %

# %% [markdown]
# #Predictive System by takinng random input
# -We will now test our model taking some input data, since only testing the model is not enough, we also need to check it against some input values given by the user.

# %%
#take input from data set any rondom withot status to predict parkinson
input_data = (95.730,132.068,91.754,0.00551,0.00006,0.00293,0.00332,0.00880,0.02093,0.191,0.01073,0.01277,0.01717,0.03218,0.01070,21.812,0.615551,0.773587,-5.498678,0.327769,2.322511,0.231571)

# %%
# changing input data format  to numpy array
input_data_numpy = np.asarray(input_data)

#reshaping the numpy array
input_data_reshape = input_data_numpy.reshape(1,-1)

#standardizing the input data
sd_data = sc.transform(input_data_reshape)

## prediction
prediction = model.predict(sd_data)
print(prediction)

if (prediction[0] == 1):
  print('The patient has Parkinson disease')
elif (prediction[0] == 0):
  print('The patient does not have Parkinson')
else:
  print('Some error in processing model')
# Out:
# [1]
# The patient has Parkinson disease

# %% [markdown]
# #Extracting the ML Model/save model

# %%
import pickle

# %%
# Save the best model to a file using pickle
with open('best_parkinsons_model.pkl', 'wb') as file:
    pickle.dump(best_model, file)

print(f"The best model has been saved as 'best_parkinsons_model.pkl'.")
# Out:
# The best model has been saved as 'best_parkinsons_model.pkl'.

# %% [markdown]
# #Conclusion:
# - The process demonstrated the effectiveness of various machine learning models in detecting Parkinson's Disease. By comparing different models, we were able to identify the most suitable one for this classification task, which was saved for potential deployment or further analysis. The project highlights the importance of model evaluation and selection, ensuring that the chosen model is not only accurate but also efficient in terms of computation and performance.
